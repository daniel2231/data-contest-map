# %% [markdown]
# # 필요한 패키지 설치

# %%
import sys
# !conda install --yes --prefix {sys.prefix} urllib
# !conda install --yes --prefix {sys.prefix} json
# !conda install --yes --prefix {sys.prefix} conda
# !conda install --yes --prefix {sys.prefix} bs4
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - urllib
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/osx-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - json
#
# Current channels:
#
# ...

# %%
from urllib.parse import urlencode, quote_plus, unquote
import bs4
import requests 
import json                 # Used to load data into JSON format
from pprint import pprint   # pretty-print

# %%
url = "http://openapi.jeonju.go.kr/rest/jeonjufood/getKoreanFoodList?serviceKey=HHLojxyI%2F7zHJuoCBMGFZ%2Fx3reetwog6Ln1QTHBsNpYZvTZ7zmQH4Ip5aFes7N6tyzCkUnr2rKz8VgG%2BIdp6Ng%3D%3D&"

response = requests.get(url).text.encode('utf-8')
xmlobj = bs4.BeautifulSoup(response, 'lxml-xml')
xmlobj
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# ...

# %%
rows = xmlobj.findAll('list')
columns = rows[1].find_all()

rowList = []
nameList = []
columnList = []

rowsLen = len(rows)

for i in range(0, rowsLen):
    columns = rows[i].find_all()
    columnsLen = len(columns)
    print(columnsLen)
    for j in range(0, columnsLen):
        if i == 0:
            nameList.append(columns[j].name)

        eachColumn = columns[j].text
        columnList.append(eachColumn)

    rowList.append(columnList)
    columnList = []
nameList.append("OpenDay")
result = pd.DataFrame(rowList, columns=nameList)
result.head()
# Out:
# 16
# 17
# 17
# 17
# 16
# 16
# 17
# 17
# 16
# 16
#   closeTime                           foodUid         holiday isPaking  \
# 0     21:00  ff808081541a4ba001549a90dc681b4a              명절        1
# 1     22:00  ff80808149a39eab014ac2e9e8163ceb           명절 당일        1
# 2     22:00  ff8080813703462a01370d27838a0256              명절        1
# 3     21:30  f600c89436a910c80136ba442323012d  설, 추석명절 당일, 익일        1
# 4     22:00  f05c6b2c35d13b700135f122c0a0093d       명절당일 및 전날        1
#
#   isReserve                                         mainImgUrl  \
# 0         1  http://food.jeonju.go.kr/planweb/upload/f05c6b...
# 1         1  http://food.jeonju.go.kr/planweb/upload/f05c6b...
# 2         1  http://food.jeonju.go.kr/planweb/upload/f05c6b...
# 3         1  http://food.jeonju.go.kr/planweb/upload/f05c6b...
# 4         1  http://food.jeonju.go.kr/planweb/upload/f05c6b...
#
#                 mainMenu                newAddr               openTime  \
# ...

# %%
import pandas as pd

df = pd.read_json(r)
df.to_csv("output.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-39cd1a28af1a> in <module>
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_json(r)
#       4 df.to_csv("output.csv")
#
# NameError: name 'r' is not defined
