# %%
import sys
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install folium
# Out:
# Requirement already satisfied: pandas in /Users/daniel/opt/anaconda3/lib/python3.8/site-packages (1.1.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/daniel/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in /Users/daniel/opt/anaconda3/lib/python3.8/site-packages (from pandas) (1.19.2)
# Requirement already satisfied: pytz>=2017.2 in /Users/daniel/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2020.1)
# Requirement already satisfied: six>=1.5 in /Users/daniel/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: folium in /Users/daniel/opt/anaconda3/lib/python3.8/site-packages (0.12.1)
# Requirement already satisfied: numpy in /Users/daniel/opt/anaconda3/lib/python3.8/site-packages (from folium) (1.19.2)
# Requirement already satisfied: jinja2>=2.9 in /Users/daniel/opt/anaconda3/lib/python3.8/site-packages (from folium) (2.11.2)
# Requirement already satisfied: requests in /Users/daniel/opt/anaconda3/lib/python3.8/site-packages (from folium) (2.24.0)
# Requirement already satisfied: branca>=0.3.0 in /Users/daniel/opt/anaconda3/lib/python3.8/site-packages (from folium) (0.4.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/daniel/opt/anaconda3/lib/python3.8/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/daniel/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/daniel/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/daniel/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/daniel/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (2.10)

# %%
import pandas as pd
import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster

# %%
data = pd.read_excel("data/result.xlsx")
data.head()
# Out:
#                            addr addrdetail                          boardSid  \
# 0    전라북도 전주시 완산구 은행로 86-2 (교동)        NaN  9be517a74f72e96b014f82d547a00a6e
# 1   전북 전주시 완산구 은행로 33-6 (풍남동3가)        NaN  9be517a74f72e96b014f82d547a00a6e
# 2       전주시 완산구 경기전길 165-5 (교동)        NaN  9be517a74f72e96b014f82d547a00a6e
# 3   전북 전주시 완산구 은행로 15-6 (풍남동2가)        NaN  9be517a74f72e96b014f82d547a00a6e
# 4  전북 전주시 완산구 전주객사5길 43-3 (고사동)        NaN  9be517a74f72e96b014f82d547a00a6e
#
#                                          dataContent  \
# 0  객실요금 주중 및 비수기------>6만원 주말 및 성수기------>8만원 자세한...
# 1   ◆ 체험정보 ○ 한복체험 --------------- 1인 5.000원(3인이상)...
# 2   군수집 1397의 객실 소개 객실명 크기(마루 제외) 숙박인원(명) 구조 특징 전...
# 3   ■ 덕만재 사이트 http://blog.naver.com/dukmanjae 로 이...
# 4  ◈아침조식서비스◈ 아메리칸브랙퍼스트(07:30am ~ 09:00am) ■ 객실요금(...
#
#                             dataSid dataTitle hanokTypeStr  \
# 0  fbadb7e8600144938e51ecb2adb2e141   은행로86.2         전통시설
# 1  f943be561327401bbcbfdd86f111bdb9       동락원         전통시설
# 2  f5596ebb7e9049a9bf6318bcff111be7  군수집 1937         전통시설
# 3  f3f115bb858d47259472d95d3f979ba2       덕만재         전통시설
# 4  f36a0af2c8564b4899d114d026830771     호텔 한성         현대시설
#
#                           homepage  \
# 0  http://blog.naver.com/white6507
# 1         http://www.jkhanok.co.kr
# 2       http://www.hanok1937.co.kr
# 3  http://blog.naver.com/dukmanjae
# 4                              NaN
#
#                                         introContent  \
# 0  은행로86.2는 한옥마을의 중심에 위치하여 전주한옥마을 여행의 접근성과 편리성을 갖...
# 1  민속문화를 사랑하는 이들이 함께 즐거이 노니는 공간 동락원(同樂園) 풍남동 소재의 ...
# 2  군수집 운영자 이근영, 이준호입니다. 집 내력부터 설명해야겠네요. 1937년 여름날...
# 3  덕만재는 50년이 넘은 전통한옥으로 마당이 넓고 한옥의 멋이 살아 있는 전통한옥숙박...
# 4  호텔한성은 전주시 중심에 위치하여 교통이 편리하고 찾기 쉽다. 한옥마을과 15분거리...
#
#                                                 memo        posx       posy  \
# 0  은행로86.2는 한옥마을의 중심에 위치하여 전주한옥마을 여행의 접근성과 편리성을 갖...  127.152693  35.812323
# 1  민속문화를 사랑하는 이들이 함께 즐거이 노니는 공간 동락원(同樂園) 풍남동 소재의 ...  127.152801  35.817674
# 2  군수집 운영자 이근영, 이준호입니다. 집 내력부터 설명해야겠네요. 1937년 여름날...  127.151590  35.812114
# 3  덕만재는 50년이 넘은 전통한옥으로 마당이 넓고 한옥의 멋이 살아 있는 전통한옥숙박...  127.152197  35.818548
# 4  호텔한성은 전주시 중심에 위치하여 교통이 편리하고 찾기 쉽다. 한옥마을과 15분거리...  127.144815  35.819838
#
#   tel  zipcode
# 0  --      NaN
# 1  --  560-033
# 2  --      NaN
# 3  --  560-032
# 4  --  560-802

# %%
map1 = folium.Map(location=[35.81,127.15], tiles='cartodbpositron', zoom_start=14)

for idx, row in data.iterrows():
    Marker([row['posy'], row['posx']]).add_to(map1)

map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_5859bd19107742f29349a1be737bb691%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_5859bd19107742f29349a1be737bb691%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_5859bd19107742f29349a1be737bb691%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_5859bd19107742f29349a1be737bb691%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B35.81%2C%20127.15%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...
